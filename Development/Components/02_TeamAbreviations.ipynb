# %% [markdown]
# # Team Abreviations & Link Structure Breakdown

# %%
# Each Team link is broken up into 3 pieces
#Philadelphia
philadelphia1 = 'https://fbref.com/en/squads/46024eeb/'
philadelphia2 = 'Philadelphia-Union-Match-Logs-All-Competitions'
philadelphia3 = 'For Phildelphia Union'
#Inter Miami
miami1 = 'https://fbref.com/en/squads/cb8b86a2/'
miami2 = 'Inter-Miami-Match-Logs-All-Competitions'
miami3 ='For Inter Miami'
#Columbus
columbus1 = 'https://fbref.com/en/squads/529ba333/'
columbus2 = 'Columbus-Crew-Match-Logs-All-Competitions'
columbus3 ='For Columbus Crew'
#FC Cincinatti
cincinnati1 = 'https://fbref.com/en/squads/e9ea41b2/'
cincinnati2 = 'FC-Cincinnati-Match-Logs-All-Competitions'
cincinnati3 ='For FC Cincinnati'
# DC United
washington1 = 'https://fbref.com/en/squads/44117292/'
washington2 = 'DC-United-Match-Logs-All-Competitions'
washington3 ='For D.C. United'
#Charlotte
charlotte1 = 'https://fbref.com/en/squads/eb57545a/'
charlotte2 = 'Charlotte-FC-Match-Logs-All-Competitions'
charlotte3 ='For FC Charlotte'
#Chacago
chicago1 = 'https://fbref.com/en/squads/f9940243/'
chicago2 = 'Chicago-Fire-Match-Logs-All-Competitions'
chicago3 ='For Chicago Fire'
#NY Red Bulls
newyorkrb1 = 'https://fbref.com/en/squads/69a0fb10/'
newyorkrb2 = 'New-York-Red-Bulls-Match-Logs-All-Competitions'
newyorkrb3 ='For New York Red Bulls'
#NYCFC
newyorkfc1 = 'https://fbref.com/en/squads/64e81410/'
newyorkfc2 = 'New-York-City-FC-Match-Logs-All-Competitions'
newyorkfc3 ='For New York City FC'
#Atlanta
atlanta1 = 'https://fbref.com/en/squads/1ebc1a5b/'
atlanta2 = 'Atlanta-United-Match-Logs-All-Competitions'
atlanta3 = 'For Atlanta United'
#Nashville
nashville1 = 'https://fbref.com/en/squads/35f1b818/'
nashville2 = 'Nashville-SC-Match-Logs-All-Competitions'
nashville3 = 'For Nashvill SC'
#Orlando City
orlando1 = 'https://fbref.com/en/squads/46ef01d0/'
orlando2 = 'Orlando-City-Match-Logs-All-Competitions'
orlando3 = 'For Orlando City'
#NE Revolution
newengland1 = 'https://fbref.com/en/squads/3c079def/'
newengland2 = 'New-England-Revolution-Match-Logs-All-Competitions'
newengland3 ='For New England Revolution'
#Toronto FC
toronto1 = 'https://fbref.com/en/squads/130f43fa/'
toronto2 = 'Toronto-FC-Match-Logs-All-Competitions'
toronto3 ='For Toronto FC'
#CF Montreal
montreal1 = 'https://fbref.com/en/squads/fc22273c/'
montreal2 = 'CF-Montreal-Match-Logs-All-Competitions'
montreal3 =' For CF Montréal'
#Vancouver
vancouver1 = 'https://fbref.com/en/squads/ab41cb90/'
vancouver2 = 'Vancouver-Whitecaps-FC-Match-Logs-All-Competitions'
vancouver3 ='For Vancouver Whitecaps FC'
#San Diego FC
sandiego1 = 'https://fbref.com/en/squads/91b092e1/'
sandiego2 = 'San-Diego-FC-Match-Logs-All-Competitions'
sandiego3 ='For San Diego FC'
#SJ Earthquakes
sanjose1 = 'https://fbref.com/en/squads/ca460650/'
sanjose2 = 'San-Jose-Earthquakes-Match-Logs-All-Competitions'
sanjose3 ='For San Jose Earthquakes'
#Minnesota
minnesota1 = 'https://fbref.com/en/squads/99ea75a6/'
minnesota2 = 'Minnesota-United-Match-Logs-All-Competitions'
minnesota3 = 'For Minnesota United'
#LAFC
losangelesfc1 = 'https://fbref.com/en/squads/81d817a3/'
losangelesfc2 = 'Los-Angeles-FC-Match-Logs-All-Competitions'
losangelesfc3 ='For Los Angeles FC'
#ST. Louis
stlouis1 = 'https://fbref.com/en/squads/bd97ac1f/'
stlouis2 = 'St-Louis-City-Match-Logs-All-Competitions'
stlouis3 ='For St. Louis City'
#Colorado
colorado1 = 'https://fbref.com/en/squads/415b4465/'
colorado2 = 'Colorado-Rapids-Match-Logs-All-Competitions'
colorado3 ='For Colorado Rapids'
#Seattle
seattle1 = 'https://fbref.com/en/squads/6218ebd4/'
seattle2 = 'Seattle-Sounders-Match-Logs-All-Competitions'
seattle3 ='For Seattle Sounders'
#FC Dallas
dallas1 = 'https://fbref.com/en/squads/15cf8f40/'
dallas2 = 'FC-Dallas-Match-Logs-All-Competitions'
dallas3 ='For FC Dallas'
#Austin
austin1 = 'https://fbref.com/en/squads/b918956d/'
austin2 = 'Austin-FC-Match-Logs-All-Competitions'
austin3 ='For FC Austin'
#Real Salt Lake
saltlake1 = 'https://fbref.com/en/squads/f7d86a43/'
saltlake2 = 'Real-Salt-Lake-Match-Logs-All-Competitions'
saltlake3 ='For Real Salt Lake'
#Portland
portland1 = 'https://fbref.com/en/squads/d076914e/'
portland2 = 'Portland-Timbers-Match-Logs-All-Competitions'
portland3 ='For Portland Timbers'
#Houston
houston1 = 'https://fbref.com/en/squads/0d885416/'
houston2 = 'Houston-Dynamo-Match-Logs-All-Competitions'
houston3 ='For Houston Dynamo'
#Sporting KC
kansascity1 = 'https://fbref.com/en/squads/4acb0537/'
kansascity2 = 'Sporting-Kansas-City-Match-Logs-All-Competitions'
kansascity3 ='For Sporting Kansas City'
#LA Galaxy
losangelesga1 = 'https://fbref.com/en/squads/d8b46897/'
losangelesga2 = 'LA-Galaxy-Match-Logs-All-Competitions'
losangelesga3 ='For LA Galaxy'

# %%
#FixtureTypes
shooting ='/matchlogs/all_comps/shooting/'
goalkeeping ='/matchlogs/all_comps/keeper/'
passing = '/matchlogs/all_comps/passing/'
passTypes = '/matchlogs/all_comps/passing_types/'
goalAndShotCreation = '/matchlogs/all_comps/gca/'
defensiveActions ='/matchlogs/all_comps/defense/'
possession = '/matchlogs/all_comps/possession/'

# %%
#https://fbref.com/en/squads/46024eeb/2025/matchlogs/all_comps/shooting/Philadelphia-Union-Match-Logs-All-Competitions
